# %%
def classify_strom(symH):
    minimum_symh = data['symH'].min()

    if minimum_symh < -250:
      return 'Super Strom'

    elif minimum_symh < -100:
      return 'Intense Strom'

    elif minimum_symh < -50:
      return 'Moderate Strom'

    elif minimum_symh < -10:
      return 'Weak Disturbance'
    else:
      return 'No strom'

# %%
import pandas as pd

def load_omni_data(filename):

    data = pd.read_csv(filename,
                    sep = r'\s+',
                    skiprows = 6,
                    skipfooter = 3,
                    engine = 'python'
                   )
    
    data.columns = [
    'Year',
    'DOY',
    'Hour',
    'Minute',
    'symH'
    ]

    return data

# %%
import os

path = 'C:\\Users\\mo alibag\\Desktop\\IIG Sushobhan Mishra\\Python for space weather analysis'
name = '7_8_sep_2017.txt'

filename = os.path.join(path,name)

data = load_omni_data(filename)
strom_type = classify_strom(data['symH'])
print(strom_type)
# Out:
# Intense Strom

# %% [markdown]
# Simplying

# %%
import os
path = 'C:\\Users\\mo alibag\\Desktop\\IIG Sushobhan Mishra\\Python for space weather analysis\\strom_data'
files = os.listdir(path)
print(files)
# Out:
# ['17_18_mar_2015.txt', '7_8_sep_2017.txt']

# %%
for name in files:
    filename = os.path.join(path, name)
    data = load_omni_data(filename)
    print(data['Year'][0:10])
    strom_type = classify_strom(data['symH'])
    print(strom_type)
# Out:
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# 5    2015
# 6    2015
# 7    2015
# 8    2015
# 9    2015
# Name: Year, dtype: int64
# Intense Strom
# 0    2017
# 1    2017
# 2    2017
# 3    2017
# 4    2017
# 5    2017
# 6    2017
# 7    2017
# 8    2017
# 9    2017
# Name: Year, dtype: int64
# Intense Strom
