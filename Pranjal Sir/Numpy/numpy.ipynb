# %% [markdown]
# Importing created library in same folder

# %%
import operation_lib as ol

print(ol.sum(1,1))
print(ol.sqr(2))
print(ol.sqrt(4))
# Out:
# 2
# 4
# 2.0

# %% [markdown]
# Pandas form dataframe from txt or readable files

# %%
import pandas as pd

dir = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260521vmin.min'

df = pd.read_csv(dir,skiprows=21,header= None,sep=r'\s+')

print(df[:].to_string())
# Out:
#                0             1    2        3      4        5        6
# 0     2026-05-21  00:00:00.000  141  38335.7  428.1  20569.3  43147.6
# 1     2026-05-21  00:01:00.000  141  38335.5  428.1  20569.3  43147.4
# 2     2026-05-21  00:02:00.000  141  38335.6  428.1  20569.3  43147.5
# 3     2026-05-21  00:03:00.000  141  38335.4  428.4  20569.6  43147.5
# 4     2026-05-21  00:04:00.000  141  38335.5  428.6  20569.8  43147.6
# 5     2026-05-21  00:05:00.000  141  38335.5  428.6  20569.8  43147.6
# 6     2026-05-21  00:06:00.000  141  38335.6  428.9  20569.9  43147.7
# 7     2026-05-21  00:07:00.000  141  38335.5  429.0  20570.1  43147.8
# 8     2026-05-21  00:08:00.000  141  38335.4  429.2  20570.2  43147.7
# 9     2026-05-21  00:09:00.000  141  38335.5  429.2  20570.2  43147.8
# 10    2026-05-21  00:10:00.000  141  38335.2  429.4  20570.2  43147.6
# 11    2026-05-21  00:11:00.000  141  38335.1  429.2  20570.2  43147.5
# ...

# %%
import pandas as pd

dir = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260521vmin.min'

df = pd.read_csv(dir,skiprows=21,header= None,sep=r'\s+')

print(df[3:12].to_string())
# Out:
#              0             1    2        3      4        5        6
# 3   2026-05-21  00:03:00.000  141  38335.4  428.4  20569.6  43147.5
# 4   2026-05-21  00:04:00.000  141  38335.5  428.6  20569.8  43147.6
# 5   2026-05-21  00:05:00.000  141  38335.5  428.6  20569.8  43147.6
# 6   2026-05-21  00:06:00.000  141  38335.6  428.9  20569.9  43147.7
# 7   2026-05-21  00:07:00.000  141  38335.5  429.0  20570.1  43147.8
# 8   2026-05-21  00:08:00.000  141  38335.4  429.2  20570.2  43147.7
# 9   2026-05-21  00:09:00.000  141  38335.5  429.2  20570.2  43147.8
# 10  2026-05-21  00:10:00.000  141  38335.2  429.4  20570.2  43147.6
# 11  2026-05-21  00:11:00.000  141  38335.1  429.2  20570.2  43147.5

# %%
import pandas as pd

dir = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260521vmin.min'

df = pd.read_csv(dir,skiprows=21,header= None,sep=r'\s+')

print(df.loc[3])
print()
print(df.iloc[3])
# Out:
# 0      2026-05-21
# 1    00:03:00.000
# 2             141
# 3         38335.4
# 4           428.4
# 5         20569.6
# 6         43147.5
# Name: 3, dtype: object
#
# 0      2026-05-21
# 1    00:03:00.000
# 2             141
# 3         38335.4
# 4           428.4
# 5         20569.6
# 6         43147.5
# Name: 3, dtype: object

# %% [markdown]
# Numpy creates arrays of dataframe

# %%
import pandas as pd
import numpy as np

dir = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260521vmin.min'

df = pd.read_csv(dir,skiprows=21,header= None,sep=r'\s+')

df.columns =['DATE','TIME','JULIAN_DAY','H','D','Z','F']

# print(np.diff(df['H']))
# print(type(np.diff(df['H'])))

# print(np.max(df['H']))
# print(np.max(df['F']))
# print(np.max(df['D']))
# print(np.max(df['Z']))

# print(np.min(df['H']))
# print(np.min(df['F']))
# print(np.min(df['D']))
# print(np.min(df['Z']))

# Amplitude_H = np.max(df['H']) - np.min(df['H'])
# print(Amplitude_H)
# Amplitude_D = np.max(df['D']) - np.min(df['D'])
# print(Amplitude_D)
# Amplitude_Z = np.max(df['Z']) - np.min(df['Z'])
# print(Amplitude_Z)
# Amplitude_F = np.max(df['F']) - np.min(df['F'])
# print(Amplitude_F)

print(np.std(df['H']))
print(np.std(df['D']))
# list1 = list(np.diff(df['H']))
# print(list1)
# print(df)
# Out:
# [-0.2  0.1 -0.2 ...  0.1  0.1 -0.1]
# <class 'numpy.ndarray'>
# 17.701462743405447

# %%
import pandas as pd
import numpy as np

dir = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260521vmin.min'

df = pd.read_csv(dir,skiprows=21,header= None,sep=r'\s+')

df.columns =['DATE','TIME','JULIAN_DAY','H','D','Z','F']

max_H = np.max(df['H'])
min_H = np.min(df['H'])

amp_H = max_H - min_H

# print(f'Maximum horizontal component: {max_H}')
# print(f'\nMinimum horizontal component: {min_H}')
# print(f'\nAmplitude of horizontal component: {amp_H}')

max_F = np.max(df['F'])
min_F = np.min(df['F'])

amp_F = max_F - min_F

# print(f'\nMaximum of total magnetic field: {max_F}')
# print(f'\nMinimum of total magnetic field: {min_F}')
# print(f'\nAmplitude of total magnetic field: {amp_F}')

# print(df['H'], df['H'] + 200)
# print(df['H'] + 200)

df1 = df[['H','D','Z','F']]
# print(df1 + 200)                    #vectorisation
# print(df[['H','D','Z','F']] + 200)
