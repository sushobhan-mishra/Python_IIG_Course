# %% [markdown]
# For 1 day, 21 May 2026

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

dir = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260521vmin.min'

df = pd.read_csv(dir,skiprows=21,header= None,sep=r'\s+')
# print(df)
df.columns =['DATE','TIME','JULIAN_DAY','H','D','Z','F']
# print(df)
df['DATETIME'] = df['DATE'] + ':' + df['TIME']
# print(df['DATETIME'])
df = df[['DATETIME', 'H','D','Z','F']]
# print(df)

df['DATETIME'] = pd.to_datetime(df['DATETIME'],format= '%Y-%m-%d:%H:%M:%S.%f')
# print(df['DATETIME'])

fig,ax = plt.subplots(4,1,layout='constrained')

plt.suptitle('Geomagnetic Data for One Day',size= 20)

ax[0].plot(df['DATETIME'],df['H'],label= 'H')
my_fmt = mdates.DateFormatter('%H')
ax[0].xaxis.set_major_formatter(my_fmt)
ax[0].set_xlim(np.min(df['DATETIME']), np.max(df['DATETIME']))
ax[0].legend(loc= 'best')
ax[0].set_ylabel('H(nT)',size= 10)

ax[1].plot(df['DATETIME'],df['D'],c='green',label= 'D')
my_fmt = mdates.DateFormatter('%H')
ax[1].xaxis.set_major_formatter(my_fmt)
ax[1].set_xlim(np.min(df['DATETIME']), np.max(df['DATETIME']))
# ax[1].set_xlabel('UT Time (in Hrs)')
ax[1].set_ylabel('D(nT)',size= 10)
ax[1].legend(loc= 'best')

ax[2].plot(df['DATETIME'],df['Z'],c='red',label= 'Z')
my_fmt = mdates.DateFormatter('%H')
ax[2].xaxis.set_major_formatter(my_fmt)
ax[2].set_xlim(np.min(df['DATETIME']), np.max(df['DATETIME']))
# ax[2].set_xlabel('UT Time (in Hrs)')
ax[2].set_ylabel('Z(nT)',size= 10)
ax[2].legend(loc= 'best')

ax[3].plot(df['DATETIME'],df['F'],c='orange',label= 'F')
my_fmt = mdates.DateFormatter('%H')
ax[3].xaxis.set_major_formatter(my_fmt)
ax[3].set_xlim(np.min(df['DATETIME']), np.max(df['DATETIME']))
ax[3].set_xlabel('UT Time (in Hrs)',size= 10)
ax[3].set_ylabel('F(nT)',size= 10)
ax[3].legend(loc= 'best')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       4 import matplotlib.dates as mdates
#       5
#       6 dir = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260521vmin.min'
#       7
# ----> 8 df = pd.read_csv(dir,skiprows=21,header= None,sep=r'\s+')
#       9 print(df)
#      10 df.columns =['DATE','TIME','JULIAN_DAY','H','D','Z','F']
#      11 # print(df)
#
# ...

# %% [markdown]
# For 2 day, 20 May 2026 to 21 May 2026

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

dir = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260520vmin.min'
df_day1 = pd.read_csv(dir,skiprows=21,header= None,sep=r'\s+')

dir1 = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260521vmin.min'
df_day2 = pd.read_csv(dir1,skiprows=21,header= None,sep=r'\s+')
# ignore_index create fresh numbering
df_combined = pd.concat([df_day1, df_day2], ignore_index=True)
# print(df_combined)

# header naming
df_combined.columns =['DATE','TIME','JULIAN_DAY','H','D','Z','F']

# combining date and time
df_combined['DATETIME'] = df_combined['DATE'] + ':' + df_combined['TIME']

# organising using header
df_combined = df_combined[['DATETIME', 'H','D','Z','F']]

# converting string to datetime
df_combined['DATETIME'] = pd.to_datetime(df_combined['DATETIME'],format= '%Y-%m-%d:%H:%M:%S.%f')

# canvas getting ready
fig,ax = plt.subplots(4,1,layout='constrained')

plt.suptitle('Geomagnetic Data for Two Days',size= 20)

ax[0].plot(df_combined['DATETIME'],df_combined['H'],label= 'H')
my_fmt = mdates.DateFormatter('%H')
ax[0].xaxis.set_major_formatter(my_fmt)
ax[0].set_xlim(np.min(df_combined['DATETIME']), np.max(df_combined['DATETIME']))
ax[0].legend(loc= 'best')
ax[0].set_ylabel('H(nT)',size= 10)

ax[1].plot(df_combined['DATETIME'],df_combined['D'],c='green',label= 'D')
my_fmt = mdates.DateFormatter('%H')
ax[1].xaxis.set_major_formatter(my_fmt)
ax[1].set_xlim(np.min(df_combined['DATETIME']), np.max(df_combined['DATETIME']))
# ax[1].set_xlabel('UT Time (in Hrs)')
ax[1].set_ylabel('D(nT)',size= 10)
ax[1].legend(loc= 'best')

ax[2].plot(df_combined['DATETIME'],df_combined['Z'],c='red',label= 'Z')
my_fmt = mdates.DateFormatter('%H')
ax[2].xaxis.set_major_formatter(my_fmt)
ax[2].set_xlim(np.min(df_combined['DATETIME']), np.max(df_combined['DATETIME']))
# ax[2].set_xlabel('UT Time (in Hrs)')
ax[2].set_ylabel('Z(nT)',size= 10)
ax[2].legend(loc= 'best')

ax[3].plot(df_combined['DATETIME'],df_combined['F'],c='orange',label= 'F')
my_fmt = mdates.DateFormatter('%H')
ax[3].xaxis.set_major_formatter(my_fmt)
ax[3].set_xlim(np.min(df_combined['DATETIME']), np.max(df_combined['DATETIME']))
ax[3].set_xlabel('UT Time (in Hrs)')
ax[3].set_ylabel('F(nT)',size= 10)
ax[3].legend(loc= 'best')

plt.show()

# %% [markdown]
# For 3 day, 19 May 2026 to 21 May 2026

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

dir2 = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260519vmin.min'
df_day3 = pd.read_csv(dir2,skiprows=21,header= None,sep=r'\s+')

dir = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260520vmin.min'
df_day1 = pd.read_csv(dir,skiprows=21,header= None,sep=r'\s+')

dir1 = r'C:\Users\mo alibag\Desktop\IIG Sushobhan Mishra\Pranjal Sir\Numpy\abg20260521vmin.min'
df_day2 = pd.read_csv(dir1,skiprows=21,header= None,sep=r'\s+')

# ignore_index create fresh numbering
df_combined = pd.concat([df_day3,df_day1, df_day2], ignore_index=True)

# header naming
df_combined.columns =['DATE','TIME','JULIAN_DAY','H','D','Z','F']

# combining date and time
df_combined['DATETIME'] = df_combined['DATE'] + ':' + df_combined['TIME']

# organising using header
df_combined = df_combined[['DATETIME', 'H','D','Z','F']]

# converting string to datetime
df_combined['DATETIME'] = pd.to_datetime(df_combined['DATETIME'],format= '%Y-%m-%d:%H:%M:%S.%f')

# canvas getting ready
fig,ax = plt.subplots(4,1,layout='constrained')

plt.suptitle('Geomagnetic Data for Two Days',size= 20)

ax[0].plot(df_combined['DATETIME'],df_combined['H'],label= 'H')
my_fmt = mdates.DateFormatter('%H')
ax[0].xaxis.set_major_formatter(my_fmt)
ax[0].set_xlim(np.min(df_combined['DATETIME']), np.max(df_combined['DATETIME']))
ax[0].legend(loc= 'best')
ax[0].set_ylabel('H(nT)',size= 10)

ax[1].plot(df_combined['DATETIME'],df_combined['D'],c='green',label= 'D')
my_fmt = mdates.DateFormatter('%H')
ax[1].xaxis.set_major_formatter(my_fmt)
ax[1].set_xlim(np.min(df_combined['DATETIME']), np.max(df_combined['DATETIME']))
# ax[1].set_xlabel('UT Time (in Hrs)')
ax[1].set_ylabel('D(nT)',size= 10)
ax[1].legend(loc= 'best')

ax[2].plot(df_combined['DATETIME'],df_combined['Z'],c='red',label= 'Z')
my_fmt = mdates.DateFormatter('%H')
ax[2].xaxis.set_major_formatter(my_fmt)
ax[2].set_xlim(np.min(df_combined['DATETIME']), np.max(df_combined['DATETIME']))
# ax[2].set_xlabel('UT Time (in Hrs)')
ax[2].set_ylabel('Z(nT)',size= 10)
ax[2].legend(loc= 'best')

ax[3].plot(df_combined['DATETIME'],df_combined['F'],c='orange',label= 'F')
my_fmt = mdates.DateFormatter('%H')
ax[3].xaxis.set_major_formatter(my_fmt)
ax[3].set_xlim(np.min(df_combined['DATETIME']), np.max(df_combined['DATETIME']))
ax[3].set_xlabel('UT Time (in Hrs)')
ax[3].set_ylabel('F(nT)',size= 10)
ax[3].legend(loc= 'best')

plt.show()
