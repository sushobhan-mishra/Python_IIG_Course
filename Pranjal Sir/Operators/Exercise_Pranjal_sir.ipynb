# %% [markdown]
# Operators and Expressions (2)(i)

# %%
a = 10
b = 3
print(a + b, a - b, a / b, a // b, a % b)
# Out:
# 13 7 3.3333333333333335 3 1

# %% [markdown]
# (ii)

# %%
X = 15 % 4 + 10 //3
print(X)
# Out:
# 6

# %% [markdown]
# (3)

# %%
print((5 + 2) * 3)
# Out:
# 21

# %%
print(10 - 4 * 2 + 6 / 3)
# Out:
# 4.0

# %%
print(10 + 5 * 2 ** 3 // 4 - 6 % 4 + (3 * (2 + 1)) and not (5 > 3 and 2 < 1))
# Out:
# True

# %% [markdown]
# (4)

# %%
X = int(input('Enter first number: '))
Y = int(input('Enter second number: '))
result = (X + Y) / 2
print(result)
# Out:
# 3.0

# %% [markdown]
# (5)

# %%
n = int(input('Enter a number: '))
if n % 2 == 0:
    print('Even')

# %% [markdown]
# (6)

# %%
n = int(input('Enter a number: '))
res = n ** 2
print(res)
# Out:
# 4

# %% [markdown]
# LOGICAL OPERATORS (1)

# %%
print( True and True) 
print(False and True) 
print(not False)
# Out:
# True
# False
# True

# %% [markdown]
# (2)

# %%
print((10 > 5) and (3 == 3)) 
print((4 != 4) or (6 > 2)) 
print(not (7 <= 7))
# Out:
# True
# True
# False

# %% [markdown]
# (3)

# %%
print(0 and 5) 
print( 10 or 0) 
print('' or 'Hello') 
print( 5 > 3 or 10 / 0) 
print(2 < 1 and 10 / 0)
# Out:
# 0
# 10
# Hello
# True
# False

# %% [markdown]
# (4)

# %%
print(None and 5) 
print(5 or None) 
print((5 and 0) or (3 and 4) and not (2 > 1))
# Out:
# None
# 5
# False

# %% [markdown]
# (5)

# %%
n = int(input('Enter a number:'))
if 10 < n < 20:
    print('Number is in between 10 and 20')
else:
    print('Number is not in between 10 and 20')
# Out:
# Number is in between 10 and 20

# %% [markdown]
# (6)

# %%
n = int(input('Enter a number:'))
if n != 5:
    print('Number is not equal to 5')
else:
    print('Number is equal to 5')
# Out:
# Number is equal to 5

# %% [markdown]
# COMPARISION OPERATORS (1)

# %%
print(10 > 5 + 3 )
print(7 * 2 == 14)
print(15 / 3 < 4 )
print(9 % 2 == 1 )
# Out:
# True
# True
# False
# True

# %% [markdown]
# (2)

# %%
print(5 + 2 > 3 * 2 )
print(12 - 4 <= 2 * 4 )
# Out:
# True
# True

# %% [markdown]
# (3)

# %%
print(100 > 50 * 2)
print(20 / 5 == 2 + 2 )
print(3 ** 2 < 10 )
# Out:
# False
# True
# True

# %% [markdown]
# (4)

# %%
print((8 + 2)> (3 * 3))
print((6 / 2) == (9 - 6))
print(5 == '5' )
# Out:
# True
# True
# False

# %% [markdown]
# (5)

# %%
print(7 == 7)
print(9 < 10)
print(5 > 3)
print(4 == 4)
# Out:
# True
# True
# True
# True

# %% [markdown]
# TYPE CONVERSION (1)

# %%
print(int(5.9))
print(float(10))
print(str(25))
print(int('10') + 5)
# Out:
# 5
# 10.0
# 25
# 15

# %%
print(float('3.14' + 2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 print(float('3.14' + 2))
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(int('5.9'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 print(int('5.9'))
#
# ValueError: invalid literal for int() with base 10: '5.9'

# %% [markdown]
# (2)

# %%
print(int(True) + int(False))
print(str(10) + str(20))
print(int(False), float(True))
# Out:
# 1
# 1020
# 0 1.0

# %% [markdown]
# (3)

# %%
print(int('abc'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 print(int('abc'))
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
print(bool(0), bool(1), bool(-5))
print(bool(''), bool('Hello'))
# Out:
# False True True
# False True

# %% [markdown]
# (4)

# %%
print(int(3.7) + float('2.3') + int(True))
print(str(int('5') + float('2.0')))
print(bool(int('0')) + int(bool('False')))
# Out:
# 6.3
# 7.0
# 1

# %% [markdown]
# (5)

# %%
print(int('0') )
print(float('10.5'))
print(str(10.5))
# Out:
# 0
# 10.5
# 10.5

# %%
print(int('10.5'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 print(int('10.5'))
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %% [markdown]
# f - STRINGS (1)

# %%
name = 'Shyam' 
print(f'Hello {name}')
# Out:
# Hello Shyam

# %%
a = 5 
b = 3 
print(f'{a} + {b} = {a + b}')
# Out:
# 5 + 3 = 8

# %%
x = 10 
print(f'Value of x is {x * 2}')
# Out:
# Value of x is 20

# %%
name = 'John'
age = 21
print(f'{name} is {age} years old')
# Out:
# John is 21 years old

# %%
print(f'{10 / 3 : .3f}')
# Out:
#  3.333

# %% [markdown]
# (4)

# %%
a = 5 
print(f'{a**2} {a +10}')
# Out:
# 25 15

# %% [markdown]
# (5)

# %%
print(f'{True} {False}')
# Out:
# True False

# %%
num =7 
print(f'{num} is {'even' if num % 2 == 0  else 'odd'}')
print(f'{int('5') + float('2.5')}')
value = 3.14159 
print(f'{value: .3f}')
a = '10' 
b = 5 
print(f'{int(a) + b}')
# Out:
# 7 is odd
# 7.5
#  3.142
# 15

# %% [markdown]
# OPERATOR PRECEDENCE(priority)

# %%
print(5  + 2 * 3)
print(10 - 4 / 2)
print(6 + 3 * 2)
print(8 * 25)
print(20 / 5 + 3 )
print(10 + 2 * 3 ** 2)
print(18 / 3 * 2)
print(7 + 6 / 3 ** 2)
print(5 + 2 * 3 - 4)
print(10 - 2 + 3 * 4)
# Out:
# 11
# 8.0
# 12
# 200
# 7.0
# 28
# 12.0
# 7.666666666666667
# 7
# 20

# %%
print(10 + 5 * 2 ** 2)
print(15 % 4 + 6 * 2)
print(20 // 3 + 2 * 3 )
print(2 ** 3 ** 2)
print(100 / 10 * 2 + 5)
print(10 + 5 * 2 ** 3 // 4 - 6 % 4)
print(5 + 3 * 4 + 8 / 2 ** 2)
# Out:
# 30
# 15
# 12
# 512
# 25.0
# 18
# 19.0
