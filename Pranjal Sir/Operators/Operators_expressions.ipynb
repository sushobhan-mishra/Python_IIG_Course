# %%
print('Hello! I am Sushobhan Mishra. I am from Odisha.')
# Out:
# Hello! I am Sushobhan Mishra.I am from Odisha.

# %%
print(1)
print(type(1))
print('Sovan')
print(type('Sovan'))
print('1')
print(type('1'))
# Out:
# 1
# <class 'int'>
# Sovan
# <class 'str'>
# 1
# <class 'str'>

# %% [markdown]
# Arithmetic Operators

# %%
print(5 * 3)
print(5 + 3)
print(5 - 3)
print(5 / 3)
print(round(5 / 3 , 2))
print(round(5 / 3 , 3))
print(5 // 3)
print(5 % 3)
print(2 ** 4)
# Out:
# 15
# 8
# 2
# 1.6666666666666667
# 1.67
# 1.667
# 1
# 2
# 16

# %%
X = 5
print('First X:' , X)
X = 6
X = 5
print('Second X:' , X)
X = 8
X = 9
X = 10
print(X)
# Out:
# First X: 5
# Second X: 5
# 5
