# %% [markdown]
# Tuple is Ordered, Unchangeable and can be duplicated.

# %%
thistuple = ("apple", "banana", "cherry") 
print(thistuple) 

thistuple = ("apple", "banana", "cherry", "apple", "cherry") 
print(thistuple) 

thistuple = ("apple", "banana", "cherry") 
print(len(thistuple))
# Out:
# ('apple', 'banana', 'cherry')
# ('apple', 'banana', 'cherry', 'apple', 'cherry')
# 3

# %% [markdown]
# Create tuple with one item

# %%
thistuple = ("apple",) 
print(type(thistuple)) 
 
#NOT a tuple 
thistuple = ("apple") 
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# Tuple can contain mix of different datatypes

# %% [markdown]
# TUPLE CONSTRUCTOR

# %%
thistuple = tuple(('apple','banana','cherry'))
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# Access Tuple items

# %%
thistuple = ("apple", "banana", "cherry") 
print(thistuple[1]) 

thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango") 
print(thistuple[:4]) 

thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango") 
print(thistuple[2:]) 

thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango") 
print(thistuple[-4:-1])
# Out:
# banana
# ('apple', 'banana', 'cherry', 'orange')
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')
# ()

# %% [markdown]
# Checking the items

# %%
thistuple = ("apple", "banana", "cherry") 
if "apple" in thistuple: 
    print("Yes, 'apple' is in the fruits tuple")
# Out:
# Yes, 'apple' is in the fruits tuple

# %% [markdown]
# Updating Tuple(tuple to list to tuple)

# %%
x = ('apple','banana','cherry')
y = list(x)
y[1] = 'kiwi'
x = tuple(y)
print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %% [markdown]
# add a item to tuple

# %%
x = ('apple','banana','cherry')
y = list(x)
y.append('Orange')
x = tuple(y)
print(x)
# Out:
# ('apple', 'banana', 'cherry', 'Orange')

# %% [markdown]
# Add tuple to tuple

# %%
thistuple = ("apple", "banana", "cherry") 
y = ("orange",) 
thistuple += y 
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %% [markdown]
# Remove item

# %%
thistuple = ("apple", "banana", "cherry") 
y = list(thistuple) 
y.remove("apple") 
thistuple = tuple(y) 
print(thistuple)
# Out:
# ('banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry") 
del thistuple 
print(thistuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 thistuple = ("apple", "banana", "cherry")
#       2 del thistuple
# ----> 3 print(thistuple)
#
# NameError: name 'thistuple' is not defined

# %% [markdown]
# Unpacking tuple

# %%
fruits = ("apple", "banana", "cherry") 
(green, yellow, red) = fruits 
print(green)  
print(yellow) 
print(red)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# using asterisk (*)

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry") 
(green, yellow, *red) = fruits 
print(green) 
print(yellow) 
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry") 
(green, *tropic, red) = fruits 
print(green) 
print(tropic) 
print(red)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry

# %% [markdown]
# Loop in tuple

# %%
fruits = ("apple", "banana", "cherry") 
for x in fruits: 
  print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# Loop through the index numbers

# %%
thistuple = ("apple", "banana", "cherry") 
for i in range(len(thistuple)): 
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %% [markdown]
# While loop

# %%
thistuple = ("apple", "banana", "cherry") 
i = 0 
while i < len(thistuple): 
  print(thistuple[i]) 
  i = i + 1
# Out:
# apple
# banana
# cherry

# %% [markdown]
# Joining tuple

# %%
tuple1 = ("a", "b", "c") 
tuple2 = (1, 2, 3) 
tuple3 = tuple1 + tuple2 
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %% [markdown]
# Multiplying tuple

# %%
fruits = ("apple", "banana", "cherry") 
mytuple = fruits * 2 
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %% [markdown]
# Tuple Methods

# %%
thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5) 
x = thistuple.count(5)         # no of duplicates
print(x)
# Out:
# 2

# %%
thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5) 
x = thistuple.index(8)    #finds the index of first occurence of the givwn number
print(x)
# Out:
# 3
