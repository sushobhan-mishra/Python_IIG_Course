# %% [markdown]
# Class is like an object constructor or BLUEPRINT for creating objects.

# %%
# Create a class
class MyClass:
    x = 5

# Create an object of MyClass
p1 = MyClass()
print(p1.x)

del p1
# Out:
# 5

# %%
class MyClass:
    x = 5

p1 = MyClass() 
p2 = MyClass()          #multiple objects for same class
p3 = MyClass() 

print(p1.x)
print(p2.x)     
print(p3.x)
# Out:
# 5
# 5
# 5

# %%
class Person:
    pass             # empty class

# %%
#without constructor, we have to set properties manually
class Person:
    pass

p1 = Person()

p1.name = "Tobias"
p1.age = 25

print(p1.name)
print(p1.age)
# Out:
# Tobias
# 25

# %%
# With constructor
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

p1 = Person("Emil", 36)

print(p1.name)
print(p1.age)
# Out:
# Emil
# 36

# %%
# Default value in constructor
class Person:
    def __init__(self, name, age =18):
        self.name = name
        self.age = age

p1 = Person("Emil")
p2 = Person("Tobias", 25)

print(p1.name, p1.age)
print(p2.name, p2.age)
# Out:
# Emil 18
# Tobias 25

# %%
#Multiple parameters in constructor

class Person:
    def __init__(self, name, age, city,country):
        self.name = name
        self.age = age
        self.city = city
        self.country = country

p1 = Person("Sovan", 21, "Bhubaneswar", "India")  

print(p1.name)
print(p1.age)
print(p1.city)  
print(p1.country)
# Out:
# Sovan
# 21
# Bhubaneswar
# India

# %%
# self represents object but self is not an object.

class Person: 
    def __init__(self, name, age): 
        self.name = name 
        self.age = age 
        
    def greet(self): 
        print("Hello, my name is " + self.name) 

p1 = Person("Alice", 30) 
p1.greet()
# Out:
# Hello, my name is Alice

# %%
class Person: 
    def __init__(self, name): 
        self.name = name 
        
    def printname(self): 
        print(self.name)

p1 = Person("Tobias") 
p2 = Person("Linus") 

p1.printname() 
p2.printname()
# Out:
# Tobias
# Linus

# %%
# self can is named anything.

from importlib import abc


class Person: 
    def __init__(myobject, name, age): 
        myobject.name = name 
        myobject.age = age 
        
    def greet(abc): 
        print("Hello, my name is " + abc.name)
         
p1 = Person("Emil", 36) 
p1.greet()
# Out:
# Hello, my name is Emil

# %%
# Accesing multiple properties using self.

class Car: 
    def __init__(self, brand, model, year): 
        self.brand = brand 
        self.model = model 
        self.year = year 
        
    def display_info(self): 
        print(f"{self.year} {self.brand} {self.model}")

car1 = Car("Toyota", "Corolla", 2020) 

car1.display_info()
# Out:
# 2020 Toyota Corolla

# %%
#Calling methods with self

class Person: 
    def __init__(self, name): 
        self.name = name 
        
    def greet(self): 
        return "Hello, " + self.name 
    
    def welcome(self): 
        message = self.greet() 
        print(message + "! Welcome to our website.") 

p1 = Person("Tobias") 
p1.welcome()
# Out:
# Hello, Tobias! Welcome to our website.

# %%
# object and class properties are variable.

class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

p1 = Person("Emil", 36) 

print(p1.name) 
print(p1.age)    

p1.age = 26 
print(p1.age)      # properties can be modified

del p1.age 
print(p1.age)         #properties can be deleted
# Out:
# Emil
# 36
# 26
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 17
#      13 p1.age = 26
#      14 print(p1.age)      # properties can be modified
#      15
#      16 del p1.age
# ---> 17 print(p1.age)
#
# AttributeError: 'Person' object has no attribute 'age'

# %%
class Person: 
    species = "Human" # Class property 
    
    def __init__(self, name): 
        self.name = name # Instance property

p1 = Person("Emil") 
p2 = Person("Tobias")

print(p1.name) 
print(p2.name) 
print(p1.species) 
print(p2.species)
# Out:
# Emil
# Tobias
# Human
# Human

# %%
# When you modify a class property, it affects all objects.

class Person: 
    lastname = "" 

    def __init__(self, name): 
        self.name = name 

p1 = Person("Linus") 
p2 = Person("Emil") 

Person.lastname = "Refsnes" 

print(p1.lastname) 
print(p2.lastname)
# Out:
# Refsnes
# Refsnes

# %%
# adding new properties to an specific object

class Person: 
    def __init__(self, name): 
        self.name = name 

p1 = Person("Tobias") 

p1.age = 25 
p1.city = "Oslo" 

print(p1.name) 
print(p1.age) 
print(p1.city)
# Out:
# Tobias
# 25
# Oslo

# %%
#class method

class Person:
    def __init__(self,name):
        self.name = name

    def greet(self):
        print('Hello, my name is ' + self.name)

p1 = Person("Emil") 
p1.greet()
# Out:
# Hello, my name is Emil

# %%
# class method with parameter

class Calculator: 
    def add(self, a, b): 
        return a + b 
    
    def multiply(self, a, b): 
        return a * b 
    
calc = Calculator()

print(calc.add(5, 3)) 
print(calc.multiply(4, 7))
# Out:
# 8
# 28

# %%
# method that access object properties.

class Person: 
    def __init__(self, name, age): 
        self.name = name 
        self.age = age 
        
    def get_info(self): 
        return f"{self.name} is {self.age} years old" 
    
p1 = Person("Tobias", 28) 
print(p1.get_info())
# Out:
# Tobias is 28 years old

# %%
# methods that modify the properties of an object.

class Person: 
    def __init__(self, name, age): 
        self.name = name 
        self.age = age 

    def celebrate_birthday(self): 
        self.age += 1 
        print(f"Happy birthday! You are now {self.age}") 

p1 = Person("Sovan", 19) 

p1.celebrate_birthday() 
p1.celebrate_birthday()
# Out:
# Happy birthday! You are now 20
# Happy birthday! You are now 21

# %%
# without  __str__() method

class Person: 
    def __init__(self, name, age): 
        self.name = name 
        self.age = age 
        
p1 = Person("Emil", 36) 
print(p1)

# %%
# with  __str__() method (controls the object what to print)

class Person: 
    def __init__(self, name, age): 
        self.name = name 
        self.age = age 

    def __str__(self):
        return f'{self.name} ({self.age})'    
        
p1 = Person("Emil", 36) 
print(p1)
# Out:
# Emil (36)

# %%
# multiple methods

class Playlist:
    def __init__(self,name):
        self.name =  name
        self.songs = []

    def add_song(self,song):
        self.songs.append(song)
        print(f'Added: {song}')

    def remove_song(self, song):
        if song in self.songs:
            self.songs.remove(song)
            print(f'Removed: {song}')

    def show_songs(self): 
        print(f"Playlist '{self.name}':") 
        for song in self.songs: 
            print(f"- {song}") 

my_playlist = Playlist("Favorites") 

my_playlist.add_song("Bohemian Rhapsody") 
my_playlist.add_song("Stairway to Heaven") 
my_playlist.show_songs()
# Out:
# Added: Bohemian Rhapsody
# Added: Stairway to Heaven
# Playlist 'Favorites':
# - Bohemian Rhapsody
# - Stairway to Heaven

# %%
# delete methods

class Person: 
    def __init__(self, name): 
        self.name = name 

    def greet(self): 
        print("Hello!") 

p1 = Person("Emil") 

del Person.greet 

p1.greet() # This will cause an error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 14
#      10 p1 = Person("Emil")
#      11
#      12 del Person.greet
#      13
# ---> 14 p1.greet() # This will cause an error
#
# AttributeError: 'Person' object has no attribute 'greet'
