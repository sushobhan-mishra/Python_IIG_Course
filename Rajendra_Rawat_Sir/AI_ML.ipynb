# %%
import numpy as np
from scipy import stats

# %% [markdown]
# # Introduction to AI/ML

# %% [markdown]
# ---

# %% [markdown]
# <b>mean/median/mode</b>

# %%
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

np.mean(speed)
# Out:
# np.float64(89.76923076923077)

# %%
np.median(speed)
# Out:
# np.float64(87.0)

# %%
x = stats.mode(speed)
print(x)
# Out:
# ModeResult(mode=np.int64(86), count=np.int64(3))

# %% [markdown]
# <b>Standard Deviation</b>

# %%
speed = [86,87,88,86,87,85,86]
np.mean(speed)
# Out:
# np.float64(86.42857142857143)

# %%
print(np.std(speed))  # low std, close to mean value.
# high std, value spread over wide range
# Out:
# 0.9035079029052513

# %% [markdown]
# #### variance

# %%
np.var(speed)
# Out:
# np.float64(0.8163265306122449)

# %% [markdown]
# <b>Percentile</b>

# %%
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
ages.sort()
print(ages)
x= np.percentile(ages,75)  # 75% of people are 43 or younger
x
# Out:
# [2, 5, 6, 7, 8, 11, 15, 25, 27, 31, 31, 32, 36, 39, 41, 43, 48, 50, 61, 80, 82]
# np.float64(43.0)

# %%
x = np.percentile(ages,90)
x
# Out:
# np.float64(61.0)

# %% [markdown]
# <b>Data distribution</b>

# %% [markdown]
# #### uniform distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.uniform(0.0,5.0,250)

plt.hist(x,5)
plt.show()

# %%
#big data distribution
x = np.random.uniform(0.0,5.0,100000)
plt.hist(x,100)
plt.show()

# %% [markdown]
# #### Normal distribution

# %% [markdown]
# ## values is concentrated around a given value

# %%
x = np.random.normal(0.0,5.0,100000)
plt.hist(x,100)   # bin = 100
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# A scatter plot with 1000 dots

# %%
x = np.random.normal(5.0, 1.0, 1000)
y = np.random.normal(10.0, 2.0, 1000)
plt.scatter(x, y)
plt.show()

# %% [markdown]
# # Regression

# %% [markdown]
# #### regression is used when you try to find the relationship between variables.
# #### This relationship is used to predict the outcome of future events in ML.

# %%
# Linear Regression

'''Linear regression uses the relationship between 
the data-points to draw a straight line through all them.'''

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
    return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
'''Predict the speed of a 10 years old car'''

x = [5,7,8,7,2,17,2,9,4,11,12,9,6] # age of car
y = [99,86,87,88,111,86,103,87,94,78,77,85,86] # speed of car

slope, intercept, r, p, std_err = stats.linregress(x, y)
# r is negative because with car age speed decreases
def myfunc(x):
    return slope * x + intercept

speed = myfunc(10)

print(speed)
# Out:
# 85.59308314937454
