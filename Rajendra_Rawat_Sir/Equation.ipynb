# %% [markdown]
# Equation of Motion

# %%
u=20
a=2
t=3
v=u+(a*t)
print(v)
# Out:
# 26

# %% [markdown]
# Sum of n natural numbers

# %%
n= int(input('Enter a number: '))
sum=n*(n+1)/2
print(sum)
# Out:
# 1035.0

# %%
n= int(input('Enter a number: '))
sum = 0
for i in range(1,n+1):
    sum = sum + i    
print(sum)
# Out:
# 55
