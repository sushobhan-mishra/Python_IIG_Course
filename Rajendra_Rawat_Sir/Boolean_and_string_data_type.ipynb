# %%
print('Hello, I am Sushobhan Mishra. I love reading books, playing piano, coding, thinking about and observing the universe.')
# Out:
# Hello, I am Sushobhan Mishra. I love reading books, playing piano, coding, thinking about and observing the universe.

# %% [markdown]
# Boolean Arithmetic

# %%
a=True
b=False
print(a or b)
print(not a)
print(not b)
print(a and b)
print(a == b)
print(a != b)
c=False
print(a or (c and b))
print((a and b) or c)
# Out:
# True
# False
# True
# False
# False
# True
# True
# False

# %%
print(10 > 9)
print(10 == 9)
print(10<9)
# Out:
# True
# False
# False

# %% [markdown]
# Concatenated String

# %%
str_1 = 'face'
str_2 = 'book'
concatenated_str= str_1 + str_2
print(concatenated_str)
concatenated_str_with_space = "Hi" + " There"
print(concatenated_str_with_space)
str_1 = 'Sushobhan'
str_2 = ' Mishra'
Full_name = str_1 + str_2
print(Full_name)
singer = 50 + 'cent'
# Out:
# facebook
# Hi There
# Sushobhan Mishra
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       7 str_1 = 'Sushobhan'
#       8 str_2 = ' Mishra'
#       9 Full_name = str_1 + str_2
#      10 print(Full_name)
# ---> 11 singer = 50 + 'cent'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
singer = str(50) + ' cent'
print(singer)
# Out:
# 50 cent

# %% [markdown]
# Repetion of string

# %%
repetition_of_string = 'wow ' * 5
print(repetition_of_string)
# Out:
# wow wow wow wow wow

# %%
fruit_string = 'apple is a fruit'
fruit_1 = 'apple'
print(fruit_1 in fruit_string) 
fruit_2 = 'banana'
print(fruit_2 in fruit_string) 

fruit_string = 'apple is a fruit'
fruit_1 = 'apple'
print(fruit_1 not in fruit_string) 
fruit_2 = 'banana'
print(fruit_2 not in fruit_string)
# Out:
# True
# False
# False
# True

# %% [markdown]
# Built in Function

# %%
count_characters = len('Corolios force')
print(count_characters)
print(max('axolotl'))
print(min('axolotl'))
# Out:
# 14
# x
# a

# %% [markdown]
# Index starts with 0.                           Range of index.......from 0 to (length-1).

# %%
Word_Phrase = 'i am hungry'
print(Word_Phrase[1])
print(Word_Phrase[2])
print(Word_Phrase[3])
print(Word_Phrase[10])
print(Word_Phrase[-1])
print(Word_Phrase[11])
# Out:
#
# a
# m
# y
# y
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 7
#       3 print(Word_Phrase[2])
#       4 print(Word_Phrase[3])
#       5 print(Word_Phrase[10])
#       6 print(Word_Phrase[-1])
# ----> 7 print(Word_Phrase[11])
#
# IndexError: string index out of range

# %% [markdown]
# String Slicing.....................................................str_name[start:end:step]

# %%
healthy_drink = 'Normal Water'
print(healthy_drink[0:3])
print(healthy_drink[:5])
print(healthy_drink[6:])
print(healthy_drink[4:4])
print(healthy_drink[6:20])
print(healthy_drink[-3:-1])
print(healthy_drink[6:-1])
print('   ')
# Out:
# Nor
# Norma
#  Water
#
#  Water
# te
#  Wate

# %%
newspaper = 'new york times'
X = newspaper[0:4]
Y = newspaper[4:9]
Z = newspaper[9:]
print(X)
print(Y)
print(Z)
print(newspaper[0:12:4])
print(newspaper[::4])
# Out:
# new
# york
# times
# ny
# ny e

# %%
A = 'Good Morning'
print(A[::2])
# Out:
# Go onn
# new york times

# %% [markdown]
# Join() method

# %%
A = 'OK '
B = 'Goodbye'
print(A + B)
num = '123'
char = 'abc'
print(num.join(char))
print(char.join(num))
# Out:
# OK Goodbye
# a123b123c
# 1abc2abc3

# %%
list_1 = ['I','am','Sovan.']
print(' '.join(list_1))
# Out:
# I am Sovan.

# %% [markdown]
# Split() Method

# %%
inventor = 'edison, tesla, marconi, newton'
Z=inventor.split(',')
print(Z)
print(type(Z))

inventor = 'edison tesla marconi newton'
Z=inventor.split()
print(Z)
print(type(Z))
# Out:
# ['edison tesla marconi newton']
# <class 'list'>
# ['edison', 'tesla', 'marconi', 'newton']
# <class 'list'>

# %% [markdown]
# String are immutable.

# %%
my_name = 'Sovan'
print(my_name[3])
my_name[2] = 'K'
# Out:
# a
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 my_name = 'Sovan'
#       2 print(my_name[3])
# ----> 3 my_name[2] = 'K'
#
# TypeError: 'str' object does not support item assignment

# %%
my_name = 'Sovan'
add = 'A'
add_name = add + my_name[1:]
print(add_name)
add = 'B'
add_name =  my_name[:-1] + add
print(add_name)
add = 'C'
add_name =  my_name[0:2] + add + my_name[3:]
print(add_name)
# Out:
# Aovan
# SovaB
# SoCan

# %% [markdown]
# Above process is lengthy so FOR LOOP is used.

# %% [markdown]
# All String method

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
print(dir(str))
print(len(dir(str)))
print(2 ** 7)
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# 81
# 128

# %%
X = 'My country is India'
print(X[0], X[3], X[11], X[14])
print(X[::-1])
Y = 'Ram'
print(Y[:-1])
Z = 'indian'
print(Z[:-3])
# Out:
# M c i I
# aidnI si yrtnuoc yM
# Ra
# ind

# %%
n = str(input('Enter a string:'))
y = len(n)
x = y//2
z = n[x]
print(n.replace( z ,'1'))
# Out:
# Mis1ra

# %%
n = input('Enter a string:')
y = len(n)//2
x = n[:y]
z = n[y+1:]
g = '*'
print(x+g+z)
print(type(n))
# Out:
# 4543*4544
# <class 'str'>

# %%
a = 'Banana'
b = a[::-1]
print(b)
A = 16
B = 15
print(A % B // A)
# Out:
# ananaB
# 0

# %%
X = 'my_report.pdf'
y = X.split('.')
print(y)
y[1]= 'xls'
print(y)
print(y[0],y[1])
# Out:
# ['my_report', 'pdf']
# ['my_report', 'xls']
# my_report xls

# %%
print(isinstance(5.0,int))
print(0xD + 0xE + 0xF)
# Out:
# False
# 42
