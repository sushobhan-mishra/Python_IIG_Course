# %%
# 1. upper()
s = "sovan"
print(s.upper())
# Out:
# SOVAN

# %%
# 2. lower()
s = "SOVAN"
print(s.lower())
# Out:
# sovan

# %%
# 3. capitalize()
s = "sovan mishra"
print(s.capitalize())
# Out:
# Sovan mishra

# %%
# 4. title()
s = "hello  world"
print(s.title())
# Out:
# Hello  World

# %%
# 5. swapcase()
s = "PyThOn"
print(s.swapcase())
# Out:
# pYtHoN

# %%
# 6. replace()
s = "I like tea"
print(s.replace("tea", "coffee"))
# Out:
# I like coffee

# %%
# 7. find()
s = "programming"
print(s.find("g"))
# Out:
# 3

# %%
# 8. index()
s = "apple"
print(s.index("p"))
# Out:
# 1

# %%
# 9. count()
s = "banana"
print(s.count("a"))
# Out:
# 3

# %%
# 10. startswith()
s = "Python"
print(s.startswith("Py"))
# Out:
# True

# %%
# 11. endswith()
s = "Python"
print(s.endswith("on"))
# Out:
# True

# %%
# 12. split()
s = "ab.lkij"
print(s.split("."))
# Out:
# ['ab', 'lkij']

# %%
# 13. join()
s = ["a", "b", "c"]
print("-".join(s))
# Out:
# a-b-c

# %%
# 14. strip()
s = " hello "
print(s.strip())
# Out:
# hello

# %%
# 15. lstrip()
s = " hello"
print(s.lstrip())
# Out:
# hello

# %%
# 16. rstrip()
s = "hello "
print(s.rstrip())
# Out:
# hello

# %%
# 17. isalpha()
s = "Hello"
print(s.isalpha())
# Out:
# True

# %%
# 18. isdigit()
s = "1234"
print(s.isdigit())
# Out:
# True

# %%
# 19. isalnum()
s = "abc123"
print(s.isalnum())
# Out:
# True

# %%
# 20. islower()
s = "hello"
print(s.islower())
# Out:
# True

# %%
# 21. isupper()
s = "HELLO"
print(s.isupper())
# Out:
# True

# %%
# 22. center()
s = "Hi"
print(s.center(10, "-"))
# Out:
# ----Hi----

# %%
# 23. zfill()
s = "25"
print(s.zfill(5))
# Out:
# 00025

# %%
# 24. partition()
s = "apple-banana"
print(s.partition("-"))
# Out:
# ('apple', '-', 'banana')

# %%
# 25. rfind()
s = "banana"
print(s.rfind("a"))
# Out:
# 5

# %%
# 26. casefold()
s = "HELLO"
print(s.casefold())
# Out:
# hello

# %%
# 27. expandtabs()
s = "H\ti"
print(s.expandtabs(4))
# Out:
# H   i

# %%
# 28. format()
age = 20
print("Age is {}".format(age))
# Out:
# Age is 20

# %%
# 29. encode()
s = "hello"
print(s.encode())
# Out:
# b'hello'

# %%
# 30. maketrans() and translate()
txt = "abc"
table = str.maketrans("a", "x")
print(txt.translate(table))
# Out:
# xbc

# %%
# 31. removeprefix()
s = "unhappy"
print(s.removeprefix("un"))
# Out:
# happy

# %%
# 32. removesuffix()
s = "playing"
print(s.removesuffix("ing"))
# Out:
# play

# %%
# 33. rsplit()
s = "a-b-c"
print(s.rsplit("-", 1))
# Out:
# ['a-b', 'c']

# %%
# 34. splitlines()
s = "Hi\nHello"
print(s.splitlines())
# Out:
# ['Hi', 'Hello']

# %%
# 35. istitle()
s = "Hello World"
print(s.istitle())
# Out:
# True

# %%
# 36. isnumeric()
s = "123"
print(s.isnumeric())
# Out:
# True

# %%
# 37. isspace()
s = "   "
print(s.isspace())
# Out:
# True

# %%
# 38. ljust()
s = "Hi"
print(s.ljust(5, "*"))
# Out:
# Hi***

# %%
# 39. rjust()
s = "Hi"
print(s.rjust(5, "*"))
# Out:
# ***Hi

# %%
# 40. format_map()
data = {'name': 'Ram'}
print("{name}".format_map(data))
# Out:
# Ram

# %%
# 41. replace multiple
s = "one two"
print(s.replace("n", "1").replace("two", "2"))
# Out:
# o1e 2

# %%
# 42. slice string
s = "Python"
print(s[0:3])
# Out:
# Pyt

# %%
# 43. reverse string
s = "Python"
print(s[::-1])
# Out:
# nohtyP

# %%
# 44. length of string
s = "Python"
print(len(s))
# Out:
# 6

# %%
# 45. concatenate
a = "Hello"
b = "World"
print(a + b)
# Out:
# HelloWorld

# %%
# 46. repeat string
s = "Hi "
print(s * 3)
# Out:
# Hi Hi Hi

# %%
# 47. check substring
s = "Python"
print("th" in s)
# Out:
# True

# %%
# 48. ascii()
s = "A"
print(ascii(s))
# Out:
# 'A'

# %%
# 49. chr()
print(chr(65))
# Out:
# A

# %%
# 50. ord()
print(ord('A'))
# Out:
# 65

# %%
# 51. min()
s = "apple"
print(min(s))
# Out:
# a

# %%
# 52. max()
s = "apple"
print(max(s))
# Out:
# p

# %%
# 53. sorted()
s = "python"
print(sorted(s))
# Out:
# ['h', 'n', 'o', 'p', 't', 'y']

# %%
# 54. tuple conversion
s = "abc"
print(tuple(s))
# Out:
# ('a', 'b', 'c')

# %%
# 55. list conversion
s = "abc"
print(list(s))
# Out:
# ['a', 'b', 'c']

# %%
# 56. set conversion
s = "banana"
print(set(s))
# Out:
# {'a', 'n', 'b'}

# %%
# 57. enumerate()
s = "abc"
print(list(enumerate(s)))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
# 58. any()
s = "abc"
print(any(s))
# Out:
# True

# %%
# 59. all()
s = "abc"
print(all(s))
# Out:
# True

# %%
# 60. comparison
a = "abc"
b = "xyz"
print(a == b)
# Out:
# False

# %%
# 61. f-string
name = "Ram"
print(f"Hello {name}")
# Out:
# Hello Ram

# %%
# 62. multiline string
s = """Hello
World"""
print(s)
# Out:
# Hello
# World

# %%
# 63. escape character
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
# 64. raw string
print(r"Hello\nWorld")
# Out:
# Hello\nWorld

# %%
# 65. string iteration
s = "abc"
for i in s:
    print(i)
# Out:
# a
# b
# c

# %%
# 66. palindrome check
s = "madam"
print(s == s[::-1])
# Out:
# True

# %%
# 67. vowel count
s = "education"
count = 0
for i in s:
    if i in "aeiou":
        count += 1
print(count)
# Out:
# 5

# %%
# 68. remove spaces
s = "h e l l o"
print(s.replace(" ", ""))
# Out:
# hello

# %%
# 69. count words
s = "I love Python"
print(len(s.split()))
# Out:
# 3

# %%
# 70. first character
s = "Python"
print(s[0])
# Out:
# P

# %%
# 71. last character
s = "Python"
print(s[-1])
# Out:
# n

# %%
# 72. string to upper manually
s = "hello"
print(s.upper())
# Out:
# HELLO

# %%
# 73. string to lower manually
s = "HELLO"
print(s.lower())
# Out:
# hello

# %%
# 74. compare lowercase
a = "Hello"
b = "hello"
print(a.lower() == b.lower())
# Out:
# True

# %%
# 75. remove newline
s = "Hello\n"
print(s.strip())
# Out:
# Hello

# %%
# 76. replace space with hyphen
s = "hello world"
print(s.replace(" ", "-"))
# Out:
# hello-world

# %%
# 77. check alphabet
s = "abc"
print(s.isalpha())
# Out:
# True

# %%
# 78. check number
s = "123"
print(s.isdigit())
# Out:
# True

# %%
# 79. reverse words
s = "I love Python"
print(" ".join(s.split()[::-1]))
# Out:
# Python love I

# %%
# 80. count character frequency
s = "banana"
print(s.count("a"))
# Out:
# 3

# %%
# 81. string comparison
a = "C"
b = "b"
print(a < b)
# Out:
# True
