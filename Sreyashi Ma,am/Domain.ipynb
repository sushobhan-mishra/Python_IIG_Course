# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel(r'C:\Users\mo alibag\Desktop\IIG_Sushobhan_Mishra\Sreyashi Ma,am\Depth_arm.xlsx', engine='openpyxl')

# print(df)

df.columns =['ARM','Top depth']
print(df)
# Out:
#            ARM  Top depth
# 0    12.072823       0.25
# 1     1.438726       0.74
# 2     0.647872       1.08
# 3     0.404617       1.62
# 4     0.388569       2.28
# ..         ...        ...
# 270   0.924567     334.04
# 271   2.079928     335.10
# 272   2.714064     336.20
# 273   3.639142     337.62
# 274   3.281169     338.12
#
# [275 rows x 2 columns]

# %%
plt.plot(df['ARM'],df['Top depth'],c = 'red')
plt.gca().invert_yaxis()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# !pip install openpyxl
# Out:
# ...
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    ---------------------------------------- 0/2 [et-xmlfile]
#    ---------------------------------------- 0/2 [et-xmlfile]
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...
