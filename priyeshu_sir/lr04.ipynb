# %%
import pandas as pd
import matplotlib.pyplot as plt

dir = r'C:\Users\mo alibag\Desktop\IIG_Sushobhan_Mishra\priyeshu sir\lr04.txt'

df = pd.read_csv(dir,skiprows=5,header= None,sep=r'\s+')
print(df)
# Out:
#            0     1     2
# 0        0.0  3.23  0.03
# 1        1.0  3.23  0.04
# 2        2.0  3.18  0.03
# 3        3.0  3.29  0.03
# 4        4.0  3.30  0.03
# ...      ...   ...   ...
# 2110  5300.0  2.91  0.06
# 2111  5305.0  2.79  0.04
# 2112  5310.0  2.79  0.09
# 2113  5315.0  2.84  0.07
# 2114  5320.0  2.91  0.09
#
# [2115 rows x 3 columns]

# %%
df.columns =['TIME','(ka)','Benthic']
print(df.columns)
print(df)
# Out:
# Index(['TIME', '(ka)', 'Benthic'], dtype='str')
#         TIME  (ka)  Benthic
# 0        0.0  3.23     0.03
# 1        1.0  3.23     0.04
# 2        2.0  3.18     0.03
# 3        3.0  3.29     0.03
# 4        4.0  3.30     0.03
# ...      ...   ...      ...
# 2110  5300.0  2.91     0.06
# 2111  5305.0  2.79     0.04
# 2112  5310.0  2.79     0.09
# 2113  5315.0  2.84     0.07
# 2114  5320.0  2.91     0.09
#
# [2115 rows x 3 columns]

# %%
plt.figure(figsize = (20,4))
plt.plot(df['TIME'],df['Benthic'])
plt.show()
